# %% [markdown]
# <a href="https://colab.research.google.com/github/leesangh92/homework/blob/main/(21_5_20)hw_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd1 = pd.read_csv('/content/sample_data/pop.csv')

# %%
pd1
# Out:
#       전입남자    전입여자    전출남자    전출여자
# 0   73,389  78,228  77,842  79,991
# 1    1,266   1,378   1,353   1,344
# 2      949   1,017   1,075   1,069
# 3    2,111   2,351   1,942   1,940
# 4    2,282   2,374   2,575   2,466
# 5    2,551   2,881   2,775   3,052
# 6    2,802   2,838   2,766   2,778
# 7    2,534   2,595   2,860   2,792
# 8    3,180   3,581   3,386   3,563
# 9    1,865   1,937   2,121   2,165
# 10   1,831   1,923   2,122   2,197
# 11   3,075   3,297   3,479   3,570
# 12   2,859   3,162   3,231   3,420
# 13   2,252   2,678   2,455   2,635
# 14   3,104   3,495   3,162   3,624
# 15   3,048   3,114   3,256   3,146
# 16   4,708   5,029   4,733   4,758
# 17   2,591   2,584   2,685   2,736
# 18   1,732   1,656   1,766   1,674
# 19   3,027   3,179   3,129   3,091
# 20   3,504   3,741   3,326   3,530
# 21   5,001   4,970   5,193   5,055
# 22   2,914   3,188   3,392   3,735
# 23   4,298   4,570   4,954   5,191
# 24   5,079   5,574   6,230   6,513
# 25   4,826   5,116   3,876   3,947

# %%
pd1['총전입'] = pd1['전입남자'] + pd1['전입여자']

# %%
pd1['총전출'] = pd1['전출남자'] + pd1['전출여자']

# %%
pd1
# Out:
#       전입남자    전입여자    전출남자    전출여자           총전입           총전출
# 0   73,389  78,228  77,842  79,991  73,38978,228  77,84279,991
# 1    1,266   1,378   1,353   1,344    1,2661,378    1,3531,344
# 2      949   1,017   1,075   1,069      9491,017    1,0751,069
# 3    2,111   2,351   1,942   1,940    2,1112,351    1,9421,940
# 4    2,282   2,374   2,575   2,466    2,2822,374    2,5752,466
# 5    2,551   2,881   2,775   3,052    2,5512,881    2,7753,052
# 6    2,802   2,838   2,766   2,778    2,8022,838    2,7662,778
# 7    2,534   2,595   2,860   2,792    2,5342,595    2,8602,792
# 8    3,180   3,581   3,386   3,563    3,1803,581    3,3863,563
# 9    1,865   1,937   2,121   2,165    1,8651,937    2,1212,165
# 10   1,831   1,923   2,122   2,197    1,8311,923    2,1222,197
# 11   3,075   3,297   3,479   3,570    3,0753,297    3,4793,570
# 12   2,859   3,162   3,231   3,420    2,8593,162    3,2313,420
# 13   2,252   2,678   2,455   2,635    2,2522,678    2,4552,635
# ...
