# %% [markdown]
# <a href="https://colab.research.google.com/github/leesangh92/homework/blob/main/(21_5_20)hw_%EC%88%98%EC%A0%95%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ===> 오후 도전
#
#
# data.go.kr
# 검색어 : 서울시 구별 인구수
#
# 파일 다운로드
# 25개구 전입남자 전입여자 전출남자 전출여자
#
# pop.csv 저장
# colab으로 업로드
# DataFrame으로 가져오기
#
# 총전입, 총전출을 구해 새로운 column을 만든다

# %%
import pandas as pd
import numpy as np

# %%
pop1 = pd.read_csv('/content/sample_data/report.csv', header = 3, thousands = ',') 
# header로 문자열을 없애고 천단위별로 표기되어있는 ','를 제거하여 숫자만을 데이터프레임으로 불러온다

# %%
pop1
# Out:
#          기간    자치구      소계     남자     여자  ...   남자.6   여자.6   계.4  남자.7  여자.7
# 0   2021.03  서울특별시  151617  73389  78228  ...  29545  28887 -6216 -4453 -1763
# 1   2021.03    종로구    2644   1266   1378  ...    492    444   -53   -87    34
# 2   2021.03     중구    1966    949   1017  ...    365    352  -178  -126   -52
# 3   2021.03    용산구    4462   2111   2351  ...    668    674   580   169   411
# 4   2021.03    성동구    4656   2282   2374  ...    891    800  -385  -293   -92
# 5   2021.03    광진구    5432   2551   2881  ...   1050   1093  -395  -224  -171
# 6   2021.03   동대문구    5640   2802   2838  ...   1077   1007    96    36    60
# 7   2021.03    중랑구    5129   2534   2595  ...   1130   1043  -523  -326  -197
# 8   2021.03    성북구    6761   3180   3581  ...   1154   1162  -188  -206    18
# 9   2021.03    강북구    3802   1865   1937  ...    669    698  -484  -256  -228
# 10  2021.03    도봉구    3754   1831   1923  ...    775    777  -565  -291  -274
# ...

# %%
pop1.head(5)
# Out:
#         기간    자치구      소계     남자     여자  ...   남자.6   여자.6   계.4  남자.7  여자.7
# 0  2021.03  서울특별시  151617  73389  78228  ...  29545  28887 -6216 -4453 -1763
# 1  2021.03    종로구    2644   1266   1378  ...    492    444   -53   -87    34
# 2  2021.03     중구    1966    949   1017  ...    365    352  -178  -126   -52
# 3  2021.03    용산구    4462   2111   2351  ...    668    674   580   169   411
# 4  2021.03    성동구    4656   2282   2374  ...    891    800  -385  -293   -92
#
# [5 rows x 26 columns]

# %%
pop1.dtypes
# Out:
# 기간      float64
# 자치구      object
# 소계        int64
# 남자        int64
# 여자        int64
# 소계.1      int64
# 남자.1      int64
# 여자.1      int64
# 소계.2      int64
# 남자.2      int64
# 여자.2      int64
# 계         int64
# 남자.3      int64
# 여자.3      int64
# 계.1       int64
# 남자.4      int64
# 여자.4      int64
# 계.2       int64
# 남자.5      int64
# 여자.5      int64
# 계.3       int64
# 남자.6      int64
# 여자.6      int64
# 계.4       int64
# 남자.7      int64
# 여자.7      int64
# dtype: object

# %% [markdown]
# 전입남자 전입여자 전출남자 전출여자
#
# pop.csv 저장 colab으로 업로드 DataFrame으로 가져오기

# %%
pop = pop1.loc[3:,['남자', '여자', '남자.1', '여자.1']]

# %%
pop.columns = ['전입남자', '전입여자', '전출남자', '전출여자']

# %%
pop
# Out:
#     전입남자  전입여자  전출남자  전출여자
# 3   2111  2351  1942  1940
# 4   2282  2374  2575  2466
# 5   2551  2881  2775  3052
# 6   2802  2838  2766  2778
# 7   2534  2595  2860  2792
# 8   3180  3581  3386  3563
# 9   1865  1937  2121  2165
# 10  1831  1923  2122  2197
# 11  3075  3297  3479  3570
# 12  2859  3162  3231  3420
# 13  2252  2678  2455  2635
# 14  3104  3495  3162  3624
# 15  3048  3114  3256  3146
# 16  4708  5029  4733  4758
# 17  2591  2584  2685  2736
# 18  1732  1656  1766  1674
# 19  3027  3179  3129  3091
# 20  3504  3741  3326  3530
# 21  5001  4970  5193  5055
# 22  2914  3188  3392  3735
# 23  4298  4570  4954  5191
# 24  5079  5574  6230  6513
# 25  4826  5116  3876  3947

# %%
type(pop)
# Out:
# pandas.core.frame.DataFrame

# %%
pop.dtypes
# Out:
# 전입남자    int64
# 전입여자    int64
# 전출남자    int64
# 전출여자    int64
# dtype: object

# %%
pop.head(5)
# Out:
#    전입남자  전입여자  전출남자  전출여자
# 3  2111  2351  1942  1940
# 4  2282  2374  2575  2466
# 5  2551  2881  2775  3052
# 6  2802  2838  2766  2778
# 7  2534  2595  2860  2792

# %% [markdown]
# 총전입, 총전출을 구해 새로운 column을 만든다

# %%
pop['총 전입'] = pop['전입남자'] + pop['전입여자'] # 값을 숫자로 인식하지 못하고 문자열로 인식한다

# %%
pop['총 전출'] = pop['전출남자'] + pop['전출여자']

# %%
pop
# Out:
#     전입남자  전입여자  전출남자  전출여자   총 전입   총 전출
# 3   2111  2351  1942  1940   4462   3882
# 4   2282  2374  2575  2466   4656   5041
# 5   2551  2881  2775  3052   5432   5827
# 6   2802  2838  2766  2778   5640   5544
# 7   2534  2595  2860  2792   5129   5652
# 8   3180  3581  3386  3563   6761   6949
# 9   1865  1937  2121  2165   3802   4286
# 10  1831  1923  2122  2197   3754   4319
# 11  3075  3297  3479  3570   6372   7049
# 12  2859  3162  3231  3420   6021   6651
# 13  2252  2678  2455  2635   4930   5090
# 14  3104  3495  3162  3624   6599   6786
# 15  3048  3114  3256  3146   6162   6402
# 16  4708  5029  4733  4758   9737   9491
# 17  2591  2584  2685  2736   5175   5421
# 18  1732  1656  1766  1674   3388   3440
# 19  3027  3179  3129  3091   6206   6220
# 20  3504  3741  3326  3530   7245   6856
# 21  5001  4970  5193  5055   9971  10248
# 22  2914  3188  3392  3735   6102   7127
# 23  4298  4570  4954  5191   8868  10145
# 24  5079  5574  6230  6513  10653  12743
# ...

# %%
pop.plot.bar()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
