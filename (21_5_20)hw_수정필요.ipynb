# %% [markdown]
# <a href="https://colab.research.google.com/github/leesangh92/homework/blob/main/(21_5_20)hw_%EC%88%98%EC%A0%95%ED%95%84%EC%9A%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ===> 오후 도전
#
#
# data.go.kr
# 검색어 : 서울시 구별 인구수
#
# 파일 다운로드
# 25개구 전입남자 전입여자 전출남자 전출여자
#
# pop.csv 저장
# colab으로 업로드
# DataFrame으로 가져오기
#
# 총전입, 총전출을 구해 새로운 column을 만든다

# %%
import pandas as pd
import numpy as np

# %%
pop1 = pd.read_csv('/content/sample_data/report.csv')

# %%
pop1
# Out:
#          기간    자치구         총이동       총이동.1  ... 시ㆍ도간이동.5     순이동   순이동.1   순이동.2
# 0        기간    자치구  총전입(①+②+④)  총전입(①+②+④)  ...    전출(⑤)     순이동     순이동     순이동
# 1        기간    자치구  총전입(①+②+④)  총전입(①+②+④)  ...    전출(⑤)     순이동     순이동     순이동
# 2        기간    자치구          소계          남자  ...       여자       계      남자      여자
# 3   2021.03  서울특별시     151,617      73,389  ...   28,887  -6,216  -4,453  -1,763
# 4   2021.03    종로구       2,644       1,266  ...      444     -53     -87      34
# 5   2021.03     중구       1,966         949  ...      352    -178    -126     -52
# 6   2021.03    용산구       4,462       2,111  ...      674     580     169     411
# 7   2021.03    성동구       4,656       2,282  ...      800    -385    -293     -92
# 8   2021.03    광진구       5,432       2,551  ...    1,093    -395    -224    -171
# 9   2021.03   동대문구       5,640       2,802  ...    1,007      96      36      60
# 10  2021.03    중랑구       5,129       2,534  ...    1,043    -523    -326    -197
# ...

# %%
pop1.head(5)
# Out:
#         기간    자치구         총이동       총이동.1  ... 시ㆍ도간이동.5     순이동   순이동.1   순이동.2
# 0       기간    자치구  총전입(①+②+④)  총전입(①+②+④)  ...    전출(⑤)     순이동     순이동     순이동
# 1       기간    자치구  총전입(①+②+④)  총전입(①+②+④)  ...    전출(⑤)     순이동     순이동     순이동
# 2       기간    자치구          소계          남자  ...       여자       계      남자      여자
# 3  2021.03  서울특별시     151,617      73,389  ...   28,887  -6,216  -4,453  -1,763
# 4  2021.03    종로구       2,644       1,266  ...      444     -53     -87      34
#
# [5 rows x 26 columns]

# %% [markdown]
# 전입남자 전입여자 전출남자 전출여자
#
# pop.csv 저장 colab으로 업로드 DataFrame으로 가져오기

# %%
pop = pop1.loc[:,['기간', '자치구', '총이동', '총이동.1', '총이동.2', '총이동.4', '총이동.5']]

# %%
pop.columns(['기간'], ['자치구'], ['총이동'], ['전입남자']. ['전입여자'], ['전출남자'], ['전출여자'])
# Out:
#   File "<ipython-input-230-521f489bd749>", line 1
#     pop.columns(['기간'], ['자치구'], ['총이동'], ['전입남자']. ['전입여자'], ['전출남자'], ['전출여자'])
#                                                     ^
# SyntaxError: invalid syntax

# %%
pop
# Out:
#          기간    자치구         총이동       총이동.1       총이동.2       총이동.4       총이동.5
# 0        기간    자치구  총전입(①+②+④)  총전입(①+②+④)  총전입(①+②+④)  총전출(①+③+⑤)  총전출(①+③+⑤)
# 1        기간    자치구  총전입(①+②+④)  총전입(①+②+④)  총전입(①+②+④)  총전출(①+③+⑤)  총전출(①+③+⑤)
# 2        기간    자치구          소계          남자          여자          남자          여자
# 3   2021.03  서울특별시     151,617      73,389      78,228      77,842      79,991
# 4   2021.03    종로구       2,644       1,266       1,378       1,353       1,344
# 5   2021.03     중구       1,966         949       1,017       1,075       1,069
# 6   2021.03    용산구       4,462       2,111       2,351       1,942       1,940
# 7   2021.03    성동구       4,656       2,282       2,374       2,575       2,466
# 8   2021.03    광진구       5,432       2,551       2,881       2,775       3,052
# 9   2021.03   동대문구       5,640       2,802       2,838       2,766       2,778
# 10  2021.03    중랑구       5,129       2,534       2,595       2,860       2,792
# ...

# %%
type(pop)
# Out:
# pandas.core.frame.DataFrame

# %%
pop.head(5)
# Out:
#         기간    자치구         총이동       총이동.1       총이동.2       총이동.4       총이동.5
# 0       기간    자치구  총전입(①+②+④)  총전입(①+②+④)  총전입(①+②+④)  총전출(①+③+⑤)  총전출(①+③+⑤)
# 1       기간    자치구  총전입(①+②+④)  총전입(①+②+④)  총전입(①+②+④)  총전출(①+③+⑤)  총전출(①+③+⑤)
# 2       기간    자치구          소계          남자          여자          남자          여자
# 3  2021.03  서울특별시     151,617      73,389      78,228      77,842      79,991
# 4  2021.03    종로구       2,644       1,266       1,378       1,353       1,344

# %% [markdown]
# 총전입, 총전출을 구해 새로운 column을 만든다

# %%
pop['move_in'] = pop.loc[3:, ['총이동1']].sum(axis = 1) + pop.loc[3: ,['총이동4']].sum(axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-220-a3be35c21ffc> in <module>()
# ----> 1 pop['move_in'] = pop.loc[3:, ['총이동1']].sum(axis = 1) + pop.loc[3: ,['총이동4']].sum(axis = 1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# ...

# %%
man_in = pop['총이동1'].sum(axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '총이동1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-227-2872112329fd> in <module>()
# ...

# %%
man_out = pop.loc[3:, ['총이동.4']]

# %%
woman_in = pop.loc[3:, ['총이동.2']]

# %%
woman_out = pop.loc[3:, ['총이동.5']]

# %%
man_in

# %%
man_out

# %%
woman_in

# %%
woman_out

# %%
move_in = man_in + woman_in

# %%
move_out =

# %%
move_in
